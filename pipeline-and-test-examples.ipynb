# %% [markdown]
# Notebook shows example of running drip_pipeline.
#
# Currently this process grabs the latest release of both the American Rivers Dam Removal Database and the USGS Dam Removal Science Database.  It then combines the two datasets into a complete list of dam removals which supports the web application Dam Removal Information Portal or DRIP.

# %%
import pandas as pd
import numpy as np
from pydrip import drip_dam
from pydrip import drip_sources

def get_data():
    #get latest American Rivers Data
    ar_url = drip_sources.get_american_rivers_data_url()
    american_rivers_df = drip_sources.read_american_rivers(ar_url)

    #get latest Dam Removal Science Data
    drd_url = drip_sources.get_science_data_url()
    dam_removal_science_df = drip_sources.read_science_data(drd_url)

    return american_rivers_df, dam_removal_science_df 

def build_drip_dams_table(dam_removal_science_df, american_rivers_df):
    #Select fields that contain dam information or american rivers id
    dam_science_df = drip_sources.get_science_subset(dam_removal_science_df, target='Dam')

    #For each dam in science database find best available data for the dam, first looking in science database and if null look in American Rivers
    all_dam_info = []
    for dam in dam_science_df.itertuples():
        removal_data = drip_dam.Dam(dam_id=dam.DamAccessionNumber)
        removal_data.science_data(dam)
        removal_data.update_missing_data(american_rivers_df)
        removal_data.add_geometry()
        all_dam_info.append(removal_data.__dict__)

    #For each dam only in American Rivers database, get AR data
    ar_only_dams = drip_sources.get_ar_only_dams(american_rivers_df, dam_science_df)
    for dam in ar_only_dams.itertuples():
        removal_data = drip_dam.Dam(dam_id=dam.AR_ID)
        removal_data.ar_dam_data(dam)
        removal_data.add_geometry()
        all_dam_info.append(removal_data.__dict__)

    all_dam_df = pd.DataFrame(all_dam_info)
    
    #select only records with geometery
    all_spatial_dam_df = all_dam_df[all_dam_df['geometry'].notna()]
    
    #Create GeoDataFrame, set crs
    #dams_gdf = gpd.GeoDataFrame(df, geometry=df['geometry'])
    #dams_gdf.crs = {'init':'epsg:4326'}     

    #export as csv
    #all_spatial_dam_df.to_csv('drip_dams.csv', sep=',', index=False)

    return all_dam_info


def main():
    #Get american rivers and dam removal science data into dataframes
    american_rivers_df, dam_removal_science_df = get_data()

    #Subset dam removal science to only dam data
    dam_science_df = drip_sources.get_science_subset(dam_removal_science_df, target='Dam')

    #Build JSON Representation of Drip Dams
    drip_dams = build_drip_dams_table(dam_removal_science_df, american_rivers_df)
    return drip_dams, dam_science_df, american_rivers_df

# %%
from IPython.display import display
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
drip_dams, dam_science_df, american_rivers_df = main()

# %%
drip_dams
# Out:
# [{'_id': '1',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'CA-055',
#   'latitude': 38.234,
#   'longitude': -121.0266,
#   'dam_built_year': 1975,
#   'dam_removed_year': 2003,
#   'dam_height_ft': 9.84252,
#   'dam_name': 'murphy creek dam',
#   'stream_name': 'murphy creek',
#   'dam_alt_name': ['sparrowk dam'],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '1',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7854488>},
#  {'_id': '2',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': 42.8203,
#   'longitude': -80.5081,
#   'dam_built_year': None,
#   'dam_removed_year': 1938,
#   'dam_height_ft': None,
#   'dam_name': 'croton dam',
#   'stream_name': 'big creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '2',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7868088>},
#  {'_id': '3',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': 43.5676,
#   'longitude': -80.6365,
#   'dam_built_year': 1885,
#   'dam_removed_year': 1941,
#   'dam_height_ft': None,
#   'dam_name': 'hawkesville dam',
#   'stream_name': 'conestoga river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '3',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7868fc8>},
#  {'_id': '4',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': 43.6448,
#   'longitude': -79.8041,
#   'dam_built_year': None,
#   'dam_removed_year': 1971,
#   'dam_height_ft': None,
#   'dam_name': 'huttonville dam',
#   'stream_name': 'credit river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '4',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7868d48>},
#  {'_id': '5',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': 43.4362,
#   'longitude': -80.3345,
#   'dam_built_year': None,
#   'dam_removed_year': 2001,
#   'dam_height_ft': None,
#   'dam_name': 'chilligo dam',
#   'stream_name': 'ellis creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '5',
#   'geometry': <shapely.geometry.point.Point at 0x18bf78684c8>},
#  {'_id': '6',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': 43.2983,
#   'longitude': -80.4744,
#   'dam_built_year': None,
#   'dam_removed_year': 1969,
#   'dam_height_ft': None,
#   'dam_name': 'greenfield dam',
#   'stream_name': 'nith river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '6',
#   'geometry': <shapely.geometry.point.Point at 0x18bf76b2a48>},
#  {'_id': '7',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': 42.8483,
#   'longitude': -80.3088,
#   'dam_built_year': 1844,
#   'dam_removed_year': 2006,
#   'dam_height_ft': None,
#   'dam_name': 'sutton dam',
#   'stream_name': 'patterson creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '7',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7a34908>},
#  {'_id': '8',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': 44.0004,
#   'longitude': -81.2832,
#   'dam_built_year': None,
#   'dam_removed_year': 1993,
#   'dam_height_ft': None,
#   'dam_name': 'teeswater dam',
#   'stream_name': 'teeswater river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '8',
#   'geometry': <shapely.geometry.point.Point at 0x18bf439a488>},
#  {'_id': '9',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': 44.5232,
#   'longitude': -80.7395,
#   'dam_built_year': None,
#   'dam_removed_year': 1992,
#   'dam_height_ft': None,
#   'dam_name': 'bognor dam',
#   'stream_name': "walter's creek",
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '9',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7a54288>},
#  {'_id': '10',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'PA-043',
#   'latitude': 40.2463,
#   'longitude': -75.6565,
#   'dam_built_year': 1755,
#   'dam_removed_year': 2000,
#   'dam_height_ft': 8.2021,
#   'dam_name': 'manatawny creek dam',
#   'stream_name': 'manatawny creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '10',
#   'geometry': <shapely.geometry.point.Point at 0x18bf76f2808>},
#  {'_id': '11',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'MT-009',
#   'latitude': 46.8716,
#   'longitude': -113.8928,
#   'dam_built_year': 1907,
#   'dam_removed_year': 2008,
#   'dam_height_ft': 27.88714,
#   'dam_name': 'milltown dam',
#   'stream_name': 'clark fork river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '11',
#   'geometry': <shapely.geometry.point.Point at 0x18bf44639c8>},
#  {'_id': '12',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OR-023',
#   'latitude': 42.42100000000001,
#   'longitude': -123.2296,
#   'dam_built_year': 1921,
#   'dam_removed_year': 2009,
#   'dam_height_ft': 39.37008,
#   'dam_name': 'savage rapids dam',
#   'stream_name': 'rogue river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '12',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7860c88>},
#  {'_id': '13',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'NC-030',
#   'latitude': 35.3812,
#   'longitude': -78.0852,
#   'dam_built_year': 1952,
#   'dam_removed_year': 1998,
#   'dam_height_ft': 17.060368,
#   'dam_name': 'quaker neck dam',
#   'stream_name': 'neuse river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '13',
#   'geometry': <shapely.geometry.point.Point at 0x18bf78605c8>},
#  {'_id': '15',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'PA-085',
#   'latitude': 40.6672,
#   'longitude': -77.5993,
#   'dam_built_year': 1975,
#   'dam_removed_year': 2004,
#   'dam_height_ft': 14.107612,
#   'dam_name': 'reedsville mill dam',
#   'stream_name': 'tea creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '15',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7860988>},
#  {'_id': '16',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'PA-021',
#   'latitude': 41.0175,
#   'longitude': -77.5258,
#   'dam_built_year': 1850,
#   'dam_removed_year': 1997,
#   'dam_height_ft': 2.952756,
#   'dam_name': "snavely's mill dam",
#   'stream_name': 'fishing creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '16',
#   'geometry': <shapely.geometry.point.Point at 0x18bf787e0c8>},
#  {'_id': '17',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'PA-017',
#   'latitude': 40.4714,
#   'longitude': -78.208,
#   'dam_built_year': 1922,
#   'dam_removed_year': 1996,
#   'dam_height_ft': 15.091864,
#   'dam_name': 'williamsburg station dam',
#   'stream_name': 'juniata river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '17',
#   'geometry': <shapely.geometry.point.Point at 0x18bf787efc8>},
#  {'_id': '18',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'SC-010',
#   'latitude': 34.7746,
#   'longitude': -82.7794,
#   'dam_built_year': 1937,
#   'dam_removed_year': 2011,
#   'dam_height_ft': 27.88714,
#   'dam_name': 'woodside dam 1',
#   'stream_name': 'twelvemile creek',
#   'dam_alt_name': ['woodside i dam'],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '18',
#   'geometry': <shapely.geometry.point.Point at 0x18bf787e4c8>},
#  {'_id': '19',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'SC-011',
#   'latitude': 34.7661,
#   'longitude': -82.792,
#   'dam_built_year': 1895,
#   'dam_removed_year': 2011,
#   'dam_height_ft': 21.981628,
#   'dam_name': 'woodside dam 2',
#   'stream_name': 'twelvemile creek',
#   'dam_alt_name': ['woodside ii dam'],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '19',
#   'geometry': <shapely.geometry.point.Point at 0x18bf787b8c8>},
#  {'_id': '20',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'MI-020',
#   'latitude': 42.0625,
#   'longitude': -85.1276,
#   'dam_built_year': 1912,
#   'dam_removed_year': 2002,
#   'dam_height_ft': 12.139108,
#   'dam_name': 'randall dam',
#   'stream_name': 'coldwater river',
#   'dam_alt_name': [],
#   'stream_alt_name': ['st. joseph river'],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '20',
#   'geometry': <shapely.geometry.point.Point at 0x18bf787bd48>},
#  {'_id': '21',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'MI-021',
#   'latitude': 44.2131,
#   'longitude': -85.8963,
#   'dam_built_year': 1912,
#   'dam_removed_year': 2003,
#   'dam_height_ft': 12.139108,
#   'dam_name': 'stronach dam',
#   'stream_name': 'pine river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '21',
#   'geometry': <shapely.geometry.point.Point at 0x18bf787bb08>},
#  {'_id': '22',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'MI-014',
#   'latitude': 46.7346,
#   'longitude': -88.443,
#   'dam_built_year': None,
#   'dam_removed_year': 1998,
#   'dam_height_ft': None,
#   'dam_name': "l'anse dam",
#   'stream_name': 'falls river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '22',
#   'geometry': <shapely.geometry.point.Point at 0x18bf787e048>},
#  {'_id': '23',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'MI-011',
#   'latitude': 44.6637,
#   'longitude': -84.7415,
#   'dam_built_year': 1914,
#   'dam_removed_year': 1991,
#   'dam_height_ft': 17.060368,
#   'dam_name': 'salling dam',
#   'stream_name': 'au sable river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '23',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7880588>},
#  {'_id': '24',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'MI-008',
#   'latitude': 43.06100000000001,
#   'longitude': -85.2508,
#   'dam_built_year': 1908,
#   'dam_removed_year': 1973,
#   'dam_height_ft': 23.950132,
#   'dam_name': 'smyrna dam',
#   'stream_name': 'flat river',
#   'dam_alt_name': ['tebbles dam'],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '24',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7880fc8>},
#  {'_id': '25',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'MI-006',
#   'latitude': 42.8231,
#   'longitude': -84.7009,
#   'dam_built_year': 1860,
#   'dam_removed_year': 1966,
#   'dam_height_ft': 4.593176,
#   'dam_name': 'wacousta dam',
#   'stream_name': 'looking glass river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '25',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7880a08>},
#  {'_id': '26',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'VA-020',
#   'latitude': 37.3274,
#   'longitude': -77.2033,
#   'dam_built_year': 1927,
#   'dam_removed_year': 2008,
#   'dam_height_ft': 9.84252,
#   'dam_name': 'lake charles dam',
#   'stream_name': 'kimages creek',
#   'dam_alt_name': ['vcu rice center dam'],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '26',
#   'geometry': <shapely.geometry.point.Point at 0x18bf78818c8>},
#  {'_id': '27',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'RI-005',
#   'latitude': 41.7644,
#   'longitude': -71.3909,
#   'dam_built_year': 1638,
#   'dam_removed_year': 2011,
#   'dam_height_ft': 4.92126,
#   'dam_name': 'pawtuxet falls dam',
#   'stream_name': 'pawtuxet river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '27',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7881d08>},
#  {'_id': '28',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'ME-005',
#   'latitude': 44.3249,
#   'longitude': -69.7697,
#   'dam_built_year': 1837,
#   'dam_removed_year': 1999,
#   'dam_height_ft': 39.37008,
#   'dam_name': 'edwards dam',
#   'stream_name': 'kennebec river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '28',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7881088>},
#  {'_id': '29',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'WI-070',
#   'latitude': 43.4585,
#   'longitude': -89.7153,
#   'dam_built_year': 1898,
#   'dam_removed_year': 2001,
#   'dam_height_ft': 11.154855999999999,
#   'dam_name': 'glenville',
#   'stream_name': 'baraboo river',
#   'dam_alt_name': ['linen mill dam', ' mcarthur dam'],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '29',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7881f88>},
#  {'_id': '30',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'WI-060',
#   'latitude': 43.4647,
#   'longitude': -89.7287,
#   'dam_built_year': 1848,
#   'dam_removed_year': 1998,
#   'dam_height_ft': 14.107612,
#   'dam_name': 'waterworks dam',
#   'stream_name': 'baraboo river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '30',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7881648>},
#  {'_id': '31',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'WI-066',
#   'latitude': 43.4666,
#   'longitude': -89.7425,
#   'dam_built_year': 1850,
#   'dam_removed_year': 2000,
#   'dam_height_ft': 14.107612,
#   'dam_name': 'oak street dam',
#   'stream_name': 'baraboo river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '31',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7883fc8>},
#  {'_id': '32',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'WI-073',
#   'latitude': 43.582,
#   'longitude': -90.133,
#   'dam_built_year': 1851,
#   'dam_removed_year': 2001,
#   'dam_height_ft': 12.139108,
#   'dam_name': 'lavalle dam',
#   'stream_name': 'baraboo river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '32',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7883a08>},
#  {'_id': '33',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'PA-053',
#   'latitude': 40.2629,
#   'longitude': -76.9791,
#   'dam_built_year': 1905,
#   'dam_removed_year': 2001,
#   'dam_height_ft': 5.905512,
#   'dam_name': 'good hope mill dam',
#   'stream_name': 'conodoguinet creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '33',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7883e88>},
#  {'_id': '34',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': 24.3615,
#   'longitude': 121.3117,
#   'dam_built_year': None,
#   'dam_removed_year': 2011,
#   'dam_height_ft': 54.13386,
#   'dam_name': 'chijiawan dam 1',
#   'stream_name': 'chijiawan stream',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '34',
#   'geometry': <shapely.geometry.point.Point at 0x18bf78849c8>},
#  {'_id': '35',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-039',
#   'latitude': 41.0301,
#   'longitude': -83.2159,
#   'dam_built_year': 1901,
#   'dam_removed_year': 2003,
#   'dam_height_ft': 7.217848000000001,
#   'dam_name': 'st. john dam',
#   'stream_name': 'sandusky river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '35',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7880988>},
#  {'_id': '36',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': 24.3582,
#   'longitude': 121.3088,
#   'dam_built_year': None,
#   'dam_removed_year': 2000,
#   'dam_height_ft': None,
#   'dam_name': 'kaoshan stream dam 1',
#   'stream_name': 'kaoshan stream',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '36',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7884fc8>},
#  {'_id': '37',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': 24.3615,
#   'longitude': 121.3035,
#   'dam_built_year': None,
#   'dam_removed_year': 2000,
#   'dam_height_ft': None,
#   'dam_name': 'kaoshan stream dam 2',
#   'stream_name': 'kaoshan stream',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '37',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7884d08>},
#  {'_id': '38',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': 24.365,
#   'longitude': 121.296,
#   'dam_built_year': None,
#   'dam_removed_year': 2000,
#   'dam_height_ft': None,
#   'dam_name': 'kaoshan stream dam 3',
#   'stream_name': 'kaoshan stream',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '38',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7886148>},
#  {'_id': '39',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': 24.3658,
#   'longitude': 121.2887,
#   'dam_built_year': None,
#   'dam_removed_year': 2000,
#   'dam_height_ft': None,
#   'dam_name': 'kaoshan stream dam 4',
#   'stream_name': 'kaoshan stream',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '39',
#   'geometry': <shapely.geometry.point.Point at 0x18bf78862c8>},
#  {'_id': '40',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'CA-044',
#   'latitude': 40.4932,
#   'longitude': -122.4708,
#   'dam_built_year': 1912,
#   'dam_removed_year': 2000,
#   'dam_height_ft': 15.091864,
#   'dam_name': 'mccormick-saeltzer dam',
#   'stream_name': 'clear creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '40',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7886688>},
#  {'_id': '41',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'AZ-004',
#   'latitude': 34.4213,
#   'longitude': -111.5759,
#   'dam_built_year': 1909,
#   'dam_removed_year': 2008,
#   'dam_height_ft': 26.24672,
#   'dam_name': 'fossil creek dam',
#   'stream_name': 'fossil creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '41',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7886cc8>},
#  {'_id': '42',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'NH-010',
#   'latitude': 42.8604,
#   'longitude': -71.4932,
#   'dam_built_year': 1734,
#   'dam_removed_year': 2008,
#   'dam_height_ft': 12.795276,
#   'dam_name': 'merrimack village dam',
#   'stream_name': 'souhegan river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '42',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7860a48>},
#  {'_id': '43',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'NY-010',
#   'latitude': 44.9896,
#   'longitude': -74.49600000000001,
#   'dam_built_year': 1913,
#   'dam_removed_year': 2009,
#   'dam_height_ft': 9.84252,
#   'dam_name': 'fort covington dam',
#   'stream_name': 'salmon river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '43',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7886a48>},
#  {'_id': '44',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OR-018',
#   'latitude': 45.3997,
#   'longitude': -122.1326,
#   'dam_built_year': 1913,
#   'dam_removed_year': 2007,
#   'dam_height_ft': 40.026247999999995,
#   'dam_name': 'marmot dam',
#   'stream_name': 'sandy river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '44',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7887b88>},
#  {'_id': '45',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'WA-013',
#   'latitude': 48.0943,
#   'longitude': -123.557,
#   'dam_built_year': 1912,
#   'dam_removed_year': 2012,
#   'dam_height_ft': 104.98688,
#   'dam_name': 'elwha dam',
#   'stream_name': 'elwha river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '45',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7887648>},
#  {'_id': '46',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'WA-014',
#   'latitude': 48.0022,
#   'longitude': -123.6,
#   'dam_built_year': 1927,
#   'dam_removed_year': 2014,
#   'dam_height_ft': 209.97376,
#   'dam_name': 'glines canyon dam',
#   'stream_name': 'elwha river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '46',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7887a88>},
#  {'_id': '47',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-068',
#   'latitude': 40.2939,
#   'longitude': -83.0604,
#   'dam_built_year': 1955,
#   'dam_removed_year': 2005,
#   'dam_height_ft': 11.48294,
#   'dam_name': 'river street dam',
#   'stream_name': 'olentangy river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '47',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7887f08>},
#  {'_id': '48',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-064',
#   'latitude': 40.3007,
#   'longitude': -83.0634,
#   'dam_built_year': 1955,
#   'dam_removed_year': 2008,
#   'dam_height_ft': 13.12336,
#   'dam_name': 'central ave dam',
#   'stream_name': 'olentangy river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '48',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7888d48>},
#  {'_id': '50',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'VA-016',
#   'latitude': 38.0208,
#   'longitude': -78.4544,
#   'dam_built_year': 1830,
#   'dam_removed_year': 2007,
#   'dam_height_ft': 9.84252,
#   'dam_name': 'woolen mills dam',
#   'stream_name': 'rivanna river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '50',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7886948>},
#  {'_id': '51',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'WI-067',
#   'latitude': 42.9729,
#   'longitude': -89.0322,
#   'dam_built_year': 1848,
#   'dam_removed_year': 2001,
#   'dam_height_ft': 10.826772,
#   'dam_name': 'rockdale dam',
#   'stream_name': 'koshkonong river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '51',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7889648>},
#  {'_id': '52',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OR-027',
#   'latitude': 45.7674,
#   'longitude': -121.5384,
#   'dam_built_year': 1913,
#   'dam_removed_year': 2012,
#   'dam_height_ft': 124.67192,
#   'dam_name': 'condit dam',
#   'stream_name': 'white salmon river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '52',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7889908>},
#  {'_id': '53',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': 41.137,
#   'longitude': -81.4812,
#   'dam_built_year': 1850,
#   'dam_removed_year': 1994,
#   'dam_height_ft': 24.278216,
#   'dam_name': 'ivex dam',
#   'stream_name': 'chagrin river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '53',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7889a48>},
#  {'_id': '54',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OR-022',
#   'latitude': 42.5629,
#   'longitude': -121.8619,
#   'dam_built_year': 1914,
#   'dam_removed_year': 2008,
#   'dam_height_ft': 11.154855999999999,
#   'dam_name': 'chiloquin dam',
#   'stream_name': 'sprague river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '54',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7886c08>},
#  {'_id': '56',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-062',
#   'latitude': 41.6585,
#   'longitude': -83.6226,
#   'dam_built_year': 1928,
#   'dam_removed_year': 2007,
#   'dam_height_ft': 8.2021,
#   'dam_name': 'secor dam',
#   'stream_name': 'ottawa river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '56',
#   'geometry': <shapely.geometry.point.Point at 0x18bf788b1c8>},
#  {'_id': '57',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-036',
#   'latitude': 41.291000000000004,
#   'longitude': -82.6374,
#   'dam_built_year': 1969,
#   'dam_removed_year': 2002,
#   'dam_height_ft': 4.92126,
#   'dam_name': 'coho dam',
#   'stream_name': 'huron river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '57',
#   'geometry': <shapely.geometry.point.Point at 0x18bf788b2c8>},
#  {'_id': '58',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': 58.4052,
#   'longitude': 8.6447,
#   'dam_built_year': 1975,
#   'dam_removed_year': 2007,
#   'dam_height_ft': None,
#   'dam_name': 'nidelva river dam 1',
#   'stream_name': 'nidelva river',
#   'dam_alt_name': ['nidelva river upper weir'],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '58',
#   'geometry': <shapely.geometry.point.Point at 0x18bf788b308>},
#  {'_id': '59',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'ME-020',
#   'latitude': 44.7347,
#   'longitude': -68.7659,
#   'dam_built_year': 1809,
#   'dam_removed_year': 2009,
#   'dam_height_ft': 9.84252,
#   'dam_name': 'mill dam',
#   'stream_name': 'sedgeunkedunk stream',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '59',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7889d08>},
#  {'_id': '61',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'MI-043',
#   'latitude': 42.6073,
#   'longitude': -85.0947,
#   'dam_built_year': 1874,
#   'dam_removed_year': 2009,
#   'dam_height_ft': 13.12336,
#   'dam_name': 'nashville dam',
#   'stream_name': 'thornapple river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '61',
#   'geometry': <shapely.geometry.point.Point at 0x18bf788b648>},
#  {'_id': '62',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': 63.1776,
#   'longitude': 18.5691,
#   'dam_built_year': 1975,
#   'dam_removed_year': 2007,
#   'dam_height_ft': 9.84252,
#   'dam_name': 'kuba dam',
#   'stream_name': 'na?tra stream',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '62',
#   'geometry': <shapely.geometry.point.Point at 0x18bf788d508>},
#  {'_id': '63',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'MI-033',
#   'latitude': 43.8521,
#   'longitude': -85.4449,
#   'dam_built_year': 1930,
#   'dam_removed_year': 2007,
#   'dam_height_ft': 11.154855999999999,
#   'dam_name': 'hersey dam',
#   'stream_name': 'hersey river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '63',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7887188>},
#  {'_id': '64',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'WI-065',
#   'latitude': 42.5737,
#   'longitude': -88.9387,
#   'dam_built_year': 1848,
#   'dam_removed_year': 2000,
#   'dam_height_ft': 12.139108,
#   'dam_name': 'shopiere dam',
#   'stream_name': 'turtle creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '64',
#   'geometry': <shapely.geometry.point.Point at 0x18bf788dbc8>},
#  {'_id': '65',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'WI-037',
#   'latitude': 43.7253,
#   'longitude': -90.5875,
#   'dam_built_year': 1865,
#   'dam_removed_year': 1992,
#   'dam_height_ft': 14.107612,
#   'dam_name': 'giles white',
#   'stream_name': 'kickapoo river',
#   'dam_alt_name': ['ontario dam'],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '65',
#   'geometry': <shapely.geometry.point.Point at 0x18bf788d888>},
#  {'_id': '66',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'WI-029',
#   'latitude': 44.4943,
#   'longitude': -89.3119,
#   'dam_built_year': 1855,
#   'dam_removed_year': 1987,
#   'dam_height_ft': 14.107612,
#   'dam_name': 'nelsonville dam',
#   'stream_name': 'tomorrow river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '66',
#   'geometry': <shapely.geometry.point.Point at 0x18bf788dcc8>},
#  {'_id': '67',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'MD-015',
#   'latitude': 39.2527,
#   'longitude': -76.7683,
#   'dam_built_year': 1900,
#   'dam_removed_year': 2010,
#   'dam_height_ft': 19.68504,
#   'dam_name': 'simkins dam',
#   'stream_name': 'patapsco river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '67',
#   'geometry': <shapely.geometry.point.Point at 0x18bf788ec08>},
#  {'_id': '68',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'NC-007',
#   'latitude': 35.5198,
#   'longitude': -79.3471,
#   'dam_built_year': 1921,
#   'dam_removed_year': 2006,
#   'dam_height_ft': 16.4042,
#   'dam_name': 'carbonton dam',
#   'stream_name': 'deep river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '68',
#   'geometry': <shapely.geometry.point.Point at 0x18bf788ee08>},
#  {'_id': '69',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'FL-001',
#   'latitude': 30.1274,
#   'longitude': -85.1773,
#   'dam_built_year': 1960,
#   'dam_removed_year': 1989,
#   'dam_height_ft': 21.981628,
#   'dam_name': 'dead lake dam',
#   'stream_name': 'chipola river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '69',
#   'geometry': <shapely.geometry.point.Point at 0x18bf788eb08>},
#  {'_id': '70',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'WI-058',
#   'latitude': 43.0579,
#   'longitude': -87.8946,
#   'dam_built_year': 1835,
#   'dam_removed_year': 1997,
#   'dam_height_ft': 17.060368,
#   'dam_name': 'north avenue dam',
#   'stream_name': 'milwaukee river',
#   'dam_alt_name': ['milwaukee dam'],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '70',
#   'geometry': <shapely.geometry.point.Point at 0x18bf788e448>},
#  {'_id': '71',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'VA-013',
#   'latitude': 38.3225,
#   'longitude': -77.4897,
#   'dam_built_year': 1910,
#   'dam_removed_year': 2005,
#   'dam_height_ft': 21.981628,
#   'dam_name': 'embrey dam',
#   'stream_name': 'rappahannock river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '71',
#   'geometry': <shapely.geometry.point.Point at 0x18bf788fe48>},
#  {'_id': '72',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'PA-313',
#   'latitude': 40.1295,
#   'longitude': -76.1971,
#   'dam_built_year': None,
#   'dam_removed_year': 1999,
#   'dam_height_ft': None,
#   'dam_name': "hellberg's dam",
#   'stream_name': 'conestoga river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '72',
#   'geometry': <shapely.geometry.point.Point at 0x18bf788bb88>},
#  {'_id': '73',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'PA-040',
#   'latitude': 40.1534,
#   'longitude': -76.1276,
#   'dam_built_year': None,
#   'dam_removed_year': 2000,
#   'dam_height_ft': None,
#   'dam_name': 'hinkletown dam',
#   'stream_name': 'conestoga river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '73',
#   'geometry': <shapely.geometry.point.Point at 0x18bf788d048>},
#  {'_id': '74',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'PA-044',
#   'latitude': 40.7844,
#   'longitude': -77.0463,
#   'dam_built_year': None,
#   'dam_removed_year': 2000,
#   'dam_height_ft': None,
#   'dam_name': 'franklin mills dam',
#   'stream_name': 'middle creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '74',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7740a48>},
#  {'_id': '75',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': 37.676,
#   'longitude': 126.9065,
#   'dam_built_year': 1975,
#   'dam_removed_year': 2006,
#   'dam_height_ft': 4.92126,
#   'dam_name': 'gongneung weir 2',
#   'stream_name': 'gongneung river',
#   'dam_alt_name': ['gokreung dam'],
#   'stream_alt_name': ['gokneung stream'],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '75',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7740608>},
#  {'_id': '76',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'WI-027',
#   'latitude': 43.4258,
#   'longitude': -88.1618,
#   'dam_built_year': 1870,
#   'dam_removed_year': 1988,
#   'dam_height_ft': 14.107612,
#   'dam_name': 'woolen mills dam',
#   'stream_name': 'milwaukee river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '76',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7740748>},
#  {'_id': '77',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'MN-005',
#   'latitude': 46.1077,
#   'longitude': -92.8632,
#   'dam_built_year': 1908,
#   'dam_removed_year': 1995,
#   'dam_height_ft': 20.013123999999998,
#   'dam_name': 'sandstone dam',
#   'stream_name': 'kettle river',
#   'dam_alt_name': ['kettle river dam'],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '77',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7742488>},
#  {'_id': '78',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'MN-007',
#   'latitude': 45.2038,
#   'longitude': -96.0194,
#   'dam_built_year': 1872,
#   'dam_removed_year': 1999,
#   'dam_height_ft': 17.060368,
#   'dam_name': 'appleton dam',
#   'stream_name': 'pomme de terre river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '78',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7740f08>},
#  {'_id': '79',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OR-017',
#   'latitude': 44.3878,
#   'longitude': -122.9334,
#   'dam_built_year': 1885,
#   'dam_removed_year': 2007,
#   'dam_height_ft': 8.2021,
#   'dam_name': 'brownsville dam',
#   'stream_name': 'calapooia river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '79',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7742588>},
#  {'_id': '81',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'MI-039',
#   'latitude': 42.3391,
#   'longitude': -83.8908,
#   'dam_built_year': 1824,
#   'dam_removed_year': 2008,
#   'dam_height_ft': 7.874015999999999,
#   'dam_name': 'dexter dam',
#   'stream_name': 'mill creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '81',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7742fc8>},
#  {'_id': '82',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'IL-016',
#   'latitude': 41.9719,
#   'longitude': -88.2798,
#   'dam_built_year': 1929,
#   'dam_removed_year': 2004,
#   'dam_height_ft': 7.874015999999999,
#   'dam_name': 'brewster creek dam',
#   'stream_name': 'brewster creek',
#   'dam_alt_name': ['ywca dam'],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '82',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7742908>},
#  {'_id': '84',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': 56.5256,
#   'longitude': 13.9417,
#   'dam_built_year': None,
#   'dam_removed_year': None,
#   'dam_height_ft': None,
#   'dam_name': 'southern sweden 1',
#   'stream_name': None,
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '84',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7743248>},
#  {'_id': '85',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': 63.4819,
#   'longitude': 15.6556,
#   'dam_built_year': None,
#   'dam_removed_year': None,
#   'dam_height_ft': None,
#   'dam_name': 'central sweden 1',
#   'stream_name': None,
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '85',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7743a08>},
#  {'_id': '86',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'WI-043',
#   'latitude': 42.8103,
#   'longitude': -89.1302,
#   'dam_built_year': 1841,
#   'dam_removed_year': 1993,
#   'dam_height_ft': 14.107612,
#   'dam_name': 'fulton dam',
#   'stream_name': 'yahara river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '86',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7743948>},
#  {'_id': '87',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'WI-052',
#   'latitude': 42.9275,
#   'longitude': -88.6855,
#   'dam_built_year': 1836,
#   'dam_removed_year': 1994,
#   'dam_height_ft': 9.84252,
#   'dam_name': 'hebron dam',
#   'stream_name': 'bark river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '87',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7743dc8>},
#  {'_id': '88',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'WI-047',
#   'latitude': 43.1812,
#   'longitude': -89.0051,
#   'dam_built_year': 1847,
#   'dam_removed_year': 1995,
#   'dam_height_ft': 11.154855999999999,
#   'dam_name': 'upper waterloo dam',
#   'stream_name': 'maunesha river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '88',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7743c48>},
#  {'_id': '89',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'WI-004',
#   'latitude': 43.1133,
#   'longitude': -89.6579,
#   'dam_built_year': 1856,
#   'dam_removed_year': 1960,
#   'dam_height_ft': 8.858268,
#   'dam_name': 'cross plains dam',
#   'stream_name': 'black earth creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '89',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7746dc8>},
#  {'_id': '90',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'WI-003',
#   'latitude': 42.9459,
#   'longitude': -89.6576,
#   'dam_built_year': 1852,
#   'dam_removed_year': 1950,
#   'dam_height_ft': 8.858268,
#   'dam_name': 'mt. vernon dam',
#   'stream_name': 'mt. vernon creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '90',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7746c48>},
#  {'_id': '91',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'IL-017',
#   'latitude': 41.8363,
#   'longitude': -88.3099,
#   'dam_built_year': 1916,
#   'dam_removed_year': 2003,
#   'dam_height_ft': 5.577427999999999,
#   'dam_name': 'south batavia dam',
#   'stream_name': 'fox river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': ['dam_built_year'],
#   'in_drd': 1,
#   'science_id': '91',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7746b88>},
#  {'_id': '92',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'PA-311',
#   'latitude': 40.1014,
#   'longitude': -77.1836,
#   'dam_built_year': 1855,
#   'dam_removed_year': 1985,
#   'dam_height_ft': 13.12336,
#   'dam_name': 'eaton-dikeman dam',
#   'stream_name': 'mountain creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '92',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7748548>},
#  {'_id': '93',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'PA-316',
#   'latitude': 40.0994,
#   'longitude': -75.4624,
#   'dam_built_year': 1789,
#   'dam_removed_year': 1920,
#   'dam_height_ft': 17.060368,
#   'dam_name': 'valley creek 1 dam',
#   'stream_name': 'valley creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '93',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7748ec8>},
#  {'_id': '94',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'PA-309',
#   'latitude': 39.9986,
#   'longitude': -76.265,
#   'dam_built_year': 1900,
#   'dam_removed_year': 1916,
#   'dam_height_ft': None,
#   'dam_name': 'big spring run 1',
#   'stream_name': 'big spring run',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '94',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7748c88>},
#  {'_id': '95',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'PA-310',
#   'latitude': 39.9739,
#   'longitude': -76.3757,
#   'dam_built_year': 1736,
#   'dam_removed_year': 1930,
#   'dam_height_ft': 19.68504,
#   'dam_name': "denlinger's mill dam",
#   'stream_name': 'west branch little conestoga creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '95',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7749788>},
#  {'_id': '96',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': 39.9375,
#   'longitude': -76.2095,
#   'dam_built_year': None,
#   'dam_removed_year': 1972,
#   'dam_height_ft': 3.28084,
#   'dam_name': 'shultz grist mill dam',
#   'stream_name': 'big beaver creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '96',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7749988>},
#  {'_id': '97',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'PA-315',
#   'latitude': 40.8476,
#   'longitude': -77.5597,
#   'dam_built_year': None,
#   'dam_removed_year': 1968,
#   'dam_height_ft': None,
#   'dam_name': 'penns creek 1 dam',
#   'stream_name': 'penns creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '97',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7a54608>},
#  {'_id': '98',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'PA-317',
#   'latitude': 39.8549,
#   'longitude': -75.7844,
#   'dam_built_year': None,
#   'dam_removed_year': 1938,
#   'dam_height_ft': None,
#   'dam_name': 'white clay creek 1 dam',
#   'stream_name': 'white clay creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '98',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7a543c8>},
#  {'_id': '99',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'PA-152',
#   'latitude': 40.1326,
#   'longitude': -76.6214,
#   'dam_built_year': 1850,
#   'dam_removed_year': 1972,
#   'dam_height_ft': 3.9370079999999996,
#   'dam_name': 'conoy creek dam',
#   'stream_name': 'conoy creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '99',
#   'geometry': <shapely.geometry.point.Point at 0x18bf4441688>},
#  {'_id': '100',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'PA-055',
#   'latitude': 40.2422,
#   'longitude': -76.3359,
#   'dam_built_year': 1902,
#   'dam_removed_year': 2001,
#   'dam_height_ft': 7.874015999999999,
#   'dam_name': 'hammer creek dam',
#   'stream_name': 'hammer creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '100',
#   'geometry': <shapely.geometry.point.Point at 0x18bf7749588>},
#  {'_id': '101',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': -25.2271,
#   'longitude': 149.0918,
#   'dam_built_year': 1898,
#   'dam_removed_year': 2002,
#   'dam_height_ft': 49.2126,
#   'dam_name': 'wellington dam',
#   'stream_name': 'bushrangers creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '101',
#   'geometry': <shapely.geometry.point.Point at 0x18bf774b788>},
#  {'_id': '102',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'WI-095',
#   'latitude': 43.4627,
#   'longitude': -89.6365,
#   'dam_built_year': None,
#   'dam_removed_year': 2003,
#   'dam_height_ft': 3.28084,
#   'dam_name': 'upper boulder creek dam',
#   'stream_name': 'boulder creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '102',
#   'geometry': <shapely.geometry.point.Point at 0x18bf77499c8>},
#  {'_id': '103',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'WI-096',
#   'latitude': 43.4646,
#   'longitude': -89.6374,
#   'dam_built_year': 1955,
#   'dam_removed_year': 2003,
#   'dam_height_ft': 8.2021,
#   'dam_name': 'lower boulder creek',
#   'stream_name': 'boulder creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '103',
#   'geometry': <shapely.geometry.point.Point at 0x18bf774be48>},
#  {'_id': '104',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-041',
#   'latitude': 41.1414,
#   'longitude': -81.4367,
#   'dam_built_year': 1818,
#   'dam_removed_year': 2005,
#   'dam_height_ft': 25.918636,
#   'dam_name': 'munroe falls dam',
#   'stream_name': 'cuyahoga river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '104',
#   'geometry': <shapely.geometry.point.Point at 0x18bf774b908>},
#  {'_id': '105',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': 47.0643,
#   'longitude': -65.3984,
#   'dam_built_year': 1955,
#   'dam_removed_year': 2006,
#   'dam_height_ft': 13.451443999999999,
#   'dam_name': 'white rapids brook dam',
#   'stream_name': 'white rapids brook',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '105',
#   'geometry': <shapely.geometry.point.Point at 0x18bf774c748>},
#  {'_id': '106',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'CT-030',
#   'latitude': 41.4939,
#   'longitude': -72.2835,
#   'dam_built_year': 1725,
#   'dam_removed_year': 2007,
#   'dam_height_ft': 4.92126,
#   'dam_name': 'zemko dam',
#   'stream_name': 'eightmile river',
#   'dam_alt_name': [],
#   'stream_alt_name': ['harris brook'],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '106',
#   'geometry': <shapely.geometry.point.Point at 0x18bf774bb48>},
#  {'_id': '107',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'NC-003',
#   'latitude': 35.3916,
#   'longitude': -78.0261,
#   'dam_built_year': 1945,
#   'dam_removed_year': 1998,
#   'dam_height_ft': 6.889764,
#   'dam_name': 'cherry hospital dam',
#   'stream_name': 'little river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '107',
#   'geometry': <shapely.geometry.point.Point at 0x18bf774cd48>},
#  {'_id': '108',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'NC-004',
#   'latitude': 35.4822,
#   'longitude': -78.1437,
#   'dam_built_year': 1928,
#   'dam_removed_year': 1999,
#   'dam_height_ft': 12.139108,
#   'dam_name': 'rains mill dam',
#   'stream_name': 'little river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '108',
#   'geometry': <shapely.geometry.point.Point at 0x18bf774c848>},
#  {'_id': '109',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'NC-008',
#   'latitude': 35.566,
#   'longitude': -78.1602,
#   'dam_built_year': 1902,
#   'dam_removed_year': 2005,
#   'dam_height_ft': 13.12336,
#   'dam_name': 'lowell mill dam',
#   'stream_name': 'little river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '109',
#   'geometry': <shapely.geometry.point.Point at 0x18bf774cdc8>},
#  {'_id': '110',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': None,
#   'latitude': 57.6222,
#   'longitude': 13.77,
#   'dam_built_year': 1765,
#   'dam_removed_year': 2007,
#   'dam_height_ft': 7.545932,
#   'dam_name': 'unnefors dam',
#   'stream_name': 'nissan stream',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '110',
#   'geometry': <shapely.geometry.point.Point at 0x18bf774da08>},
#  {'_id': '111',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'CA-102',
#   'latitude': 40.442,
#   'longitude': -121.4077,
#   'dam_built_year': 1931,
#   'dam_removed_year': 2011,
#   'dam_height_ft': None,
#   'dam_name': 'dream lake dam',
#   'stream_name': 'Hot Springs Creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '111',
#   'geometry': <shapely.geometry.point.Point at 0x18bf774d188>},
#  {'_id': '112',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'MN-006',
#   'latitude': 46.7253,
#   'longitude': -95.6973,
#   'dam_built_year': 1923,
#   'dam_removed_year': 1999,
#   'dam_height_ft': 19.028872,
#   'dam_name': 'frazee dam',
#   'stream_name': 'otter tail river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '112',
#   'geometry': <shapely.geometry.point.Point at 0x18bf774dac8>},
#  {'_id': '113',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'CT-011',
#   'latitude': 41.5725,
#   'longitude': -73.0535,
#   'dam_built_year': 1750,
#   'dam_removed_year': 1999,
#   'dam_height_ft': 11.154855999999999,
#   'dam_name': 'anaconda dam',
#   'stream_name': 'naugatuck river',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '113',
#   'geometry': <shapely.geometry.point.Point at 0x18bf774dc08>},
#  {'_id': '114',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OR-014',
#   'latitude': 43.7154,
#   'longitude': -122.7154,
#   'dam_built_year': 1925,
#   'dam_removed_year': 2003,
#   'dam_height_ft': 10.498688000000001,
#   'dam_name': 'dinner creek dam',
#   'stream_name': 'dinner creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '114',
#   'geometry': <shapely.geometry.point.Point at 0x18bf774ec48>},
#  {'_id': '115',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'CA-033',
#   'latitude': 41.3305,
#   'longitude': -124.0232,
#   'dam_built_year': 1936,
#   'dam_removed_year': 1989,
#   'dam_height_ft': 6.889764,
#   'dam_name': 'lost man dam',
#   'stream_name': 'lost man creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'science_id': '115',
# ...
#   'stream_name': 'Brannon Fork',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77e7e48>},
#  {'_id': 'OH-022',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-022',
#   'latitude': 39.76667,
#   'longitude': -81.7083,
#   'dam_built_year': nan,
#   'dam_removed_year': 1987.0,
#   'dam_height_ft': 17.0,
#   'dam_name': 'Ohio Power Company Pond Dam',
#   'stream_name': 'Collins Fork',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77e7f48>},
#  {'_id': 'OH-023',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-023',
#   'latitude': 39.33889,
#   'longitude': -82.1778,
#   'dam_built_year': nan,
#   'dam_removed_year': 1988.0,
#   'dam_height_ft': 42.0,
#   'dam_name': 'Poston Fresh Water Pond Dam',
#   'stream_name': 'Tributary to Hamley Run',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ea088>},
#  {'_id': 'OH-024',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-024',
#   'latitude': 40.20278,
#   'longitude': -80.9464,
#   'dam_built_year': nan,
#   'dam_removed_year': 1988.0,
#   'dam_height_ft': 13.0,
#   'dam_name': 'Georgetoen Freshwater Dam',
#   'stream_name': 'Tributary to South Fork',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ea188>},
#  {'_id': 'OH-027',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-027',
#   'latitude': nan,
#   'longitude': nan,
#   'dam_built_year': nan,
#   'dam_removed_year': 1989.0,
#   'dam_height_ft': nan,
#   'dam_name': 'Chapel Church Lake Dam',
#   'stream_name': 'Tributary to Silver Creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ea288>},
#  {'_id': 'OH-028',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-028',
#   'latitude': 40.0429,
#   'longitude': -81.1608,
#   'dam_built_year': nan,
#   'dam_removed_year': 1989.0,
#   'dam_height_ft': 25.0,
#   'dam_name': 'State Route 800 Dam',
#   'stream_name': 'Tributary to Spencer Creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ea388>},
#  {'_id': 'OH-029',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-029',
#   'latitude': 39.89377,
#   'longitude': -83.2187,
#   'dam_built_year': nan,
#   'dam_removed_year': 1990.0,
#   'dam_height_ft': 12.0,
#   'dam_name': 'Okie Rice Dam',
#   'stream_name': 'Little Darby Creek',
#   'dam_alt_name': ['Little Darby Dam'],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ea608>},
#  {'_id': 'OH-030',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-030',
#   'latitude': nan,
#   'longitude': nan,
#   'dam_built_year': nan,
#   'dam_removed_year': 1990.0,
#   'dam_height_ft': 14.0,
#   'dam_name': 'Slippery Run Dam',
#   'stream_name': nan,
#   'dam_alt_name': ['Stahl'],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ea748>},
#  {'_id': 'OH-031',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-031',
#   'latitude': 40.50974,
#   'longitude': -80.7305,
#   'dam_built_year': nan,
#   'dam_removed_year': 1991.0,
#   'dam_height_ft': 15.0,
#   'dam_name': 'Toronto Band Father’s Lake Dam',
#   'stream_name': 'Town Fork',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ea6c8>},
#  {'_id': 'OH-032',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-032',
#   'latitude': 39.363890000000005,
#   'longitude': -82.12,
#   'dam_built_year': nan,
#   'dam_removed_year': 1991.0,
#   'dam_height_ft': 17.0,
#   'dam_name': 'Cottingham Lake Dam',
#   'stream_name': 'Tributary to Hocking River',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ea808>},
#  {'_id': 'OH-033',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-033',
#   'latitude': nan,
#   'longitude': nan,
#   'dam_built_year': nan,
#   'dam_removed_year': 1991.0,
#   'dam_height_ft': 15.0,
#   'dam_name': 'Armington Dam #2',
#   'stream_name': nan,
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ea908>},
#  {'_id': 'OH-034',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-034',
#   'latitude': 41.10709,
#   'longitude': -84.4185,
#   'dam_built_year': nan,
#   'dam_removed_year': 1992.0,
#   'dam_height_ft': 18.0,
#   'dam_name': 'Burt Lake Dam',
#   'stream_name': 'Tributary to Little Auglaize River',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77eaa08>},
#  {'_id': 'OH-035',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-035',
#   'latitude': 39.76413,
#   'longitude': -83.9017,
#   'dam_built_year': 1910.0,
#   'dam_removed_year': 1997.0,
#   'dam_height_ft': 8.0,
#   'dam_name': 'Jacoby Road Dam',
#   'stream_name': 'Little Miami River',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77eab08>},
#  {'_id': 'OH-037',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-037',
#   'latitude': 40.24256,
#   'longitude': -83.0604,
#   'dam_built_year': nan,
#   'dam_removed_year': 2002.0,
#   'dam_height_ft': 4.0,
#   'dam_name': 'Dennison Dam',
#   'stream_name': 'Olentangy River',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77eac08>},
#  {'_id': 'OH-038',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-038',
#   'latitude': 41.69187,
#   'longitude': -83.675,
#   'dam_built_year': nan,
#   'dam_removed_year': 2003.0,
#   'dam_height_ft': 5.0,
#   'dam_name': 'Camp Miaconda Dam',
#   'stream_name': 'Ottawa River',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ead08>},
#  {'_id': 'OH-042',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-042',
#   'latitude': 39.96407,
#   'longitude': -82.9479,
#   'dam_built_year': nan,
#   'dam_removed_year': 2008.0,
#   'dam_height_ft': 4.0,
#   'dam_name': 'Wolfe Park Dam',
#   'stream_name': 'Alum Creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77eae08>},
#  {'_id': 'OH-043',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-043',
#   'latitude': 39.97605,
#   'longitude': -82.9452,
#   'dam_built_year': nan,
#   'dam_removed_year': 2008.0,
#   'dam_height_ft': 4.0,
#   'dam_name': 'Nelson Park Dam',
#   'stream_name': 'Alum Creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77eaf08>},
#  {'_id': 'OH-044',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-044',
#   'latitude': 39.871047999999995,
#   'longitude': -84.286858,
#   'dam_built_year': nan,
#   'dam_removed_year': 2009.0,
#   'dam_height_ft': 8.0,
#   'dam_name': 'Englewood Reserve Dam',
#   'stream_name': 'Stillwater River',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77eafc8>},
#  {'_id': 'OH-045',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-045',
#   'latitude': 40.32271,
#   'longitude': -83.0704,
#   'dam_built_year': 1941.0,
#   'dam_removed_year': 2010.0,
#   'dam_height_ft': 4.0,
#   'dam_name': 'Panhandle Road Dam',
#   'stream_name': 'Olentangy River',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ec148>},
#  {'_id': 'OH-046',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-046',
#   'latitude': 41.56038,
#   'longitude': -81.5298,
#   'dam_built_year': 1933.0,
#   'dam_removed_year': 2010.0,
#   'dam_height_ft': 6.0,
#   'dam_name': 'East Branch Dam',
#   'stream_name': 'Euclid Creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ec248>},
#  {'_id': 'OH-047',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-047',
#   'latitude': nan,
#   'longitude': nan,
#   'dam_built_year': nan,
#   'dam_removed_year': 2010.0,
#   'dam_height_ft': nan,
#   'dam_name': 'Williamsport Dam ',
#   'stream_name': 'Deer Creek',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ec348>},
#  {'_id': 'OH-048',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-048',
#   'latitude': 40.85837,
#   'longitude': -84.2898,
#   'dam_built_year': nan,
#   'dam_removed_year': 2012.0,
#   'dam_height_ft': 6.0,
#   'dam_name': 'German Farm Dam',
#   'stream_name': 'Auglaize River',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ec448>},
#  {'_id': 'OH-050',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-050',
#   'latitude': 41.366038,
#   'longitude': -81.85469,
#   'dam_built_year': 1980.0,
#   'dam_removed_year': 2012.0,
#   'dam_height_ft': 3.0,
#   'dam_name': 'Baldwin Creek Dam 1',
#   'stream_name': 'Rocky River',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ec548>},
#  {'_id': 'OH-051',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-051',
#   'latitude': 41.36528,
#   'longitude': -81.8554,
#   'dam_built_year': 1980.0,
#   'dam_removed_year': 2012.0,
#   'dam_height_ft': 1.5,
#   'dam_name': 'Baldwin Creek Dam 2',
#   'stream_name': 'Rocky River',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ec648>},
#  {'_id': 'OH-052',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-052',
#   'latitude': 41.3611,
#   'longitude': -81.8531,
#   'dam_built_year': 1980.0,
#   'dam_removed_year': 2012.0,
#   'dam_height_ft': 5.0,
#   'dam_name': 'Baldwin Creek Dam 3',
#   'stream_name': 'Rocky River',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ec748>},
#  {'_id': 'OH-053',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-053',
#   'latitude': 41.137029999999996,
#   'longitude': -81.4816,
#   'dam_built_year': nan,
#   'dam_removed_year': 2013.0,
#   'dam_height_ft': nan,
#   'dam_name': 'LeFever Powerhouse Dam',
#   'stream_name': 'Cuyahoga River',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ec848>},
#  {'_id': 'OH-054',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-054',
#   'latitude': 41.13321,
#   'longitude': -81.4823,
#   'dam_built_year': nan,
#   'dam_removed_year': 2013.0,
#   'dam_height_ft': nan,
#   'dam_name': 'Sheraton Mill Dam',
#   'stream_name': 'Cuyahoga River',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ec948>},
#  {'_id': 'OH-055',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-055',
#   'latitude': 41.23775,
#   'longitude': -81.5737,
#   'dam_built_year': nan,
#   'dam_removed_year': 2014.0,
#   'dam_height_ft': 15.0,
#   'dam_name': 'Fink Dam',
#   'stream_name': 'Unnamed tributary to Cuyahoga River',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77eca48>},
#  {'_id': 'OH-056',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-056',
#   'latitude': 41.2384,
#   'longitude': -81.5847,
#   'dam_built_year': nan,
#   'dam_removed_year': 2014.0,
#   'dam_height_ft': 20.0,
#   'dam_name': 'Harpham Dam',
#   'stream_name': 'Unnamed tributary to Cuyahoga River',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ecb48>},
#  {'_id': 'OH-057',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-057',
#   'latitude': 41.227779999999996,
#   'longitude': -81.5583,
#   'dam_built_year': nan,
#   'dam_removed_year': 2014.0,
#   'dam_height_ft': 15.0,
#   'dam_name': 'Heart Break Dam',
#   'stream_name': 'Unnamed tributary to Cuyahoga River',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ecc48>},
#  {'_id': 'OH-058',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-058',
#   'latitude': 41.23892,
#   'longitude': -81.5707,
#   'dam_built_year': nan,
#   'dam_removed_year': 2014.0,
#   'dam_height_ft': 25.0,
#   'dam_name': 'Oscada Dam',
#   'stream_name': 'Unnamed tributary to Cuyahoga River',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ecd48>},
#  {'_id': 'OH-059',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-059',
#   'latitude': 41.20471,
#   'longitude': -81.5216,
#   'dam_built_year': nan,
#   'dam_removed_year': 2014.0,
#   'dam_height_ft': 20.0,
#   'dam_name': 'Pittinger Dam',
#   'stream_name': 'Unnamed tributary to Cuyahoga River',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ece48>},
#  {'_id': 'OH-060',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-060',
#   'latitude': 39.97701,
#   'longitude': -84.325,
#   'dam_built_year': 1918.0,
#   'dam_removed_year': 2014.0,
#   'dam_height_ft': 13.0,
#   'dam_name': 'West Milton Dam',
#   'stream_name': 'Stillwater River',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ecf48>},
#  {'_id': 'OH-063',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-063',
#   'latitude': nan,
#   'longitude': nan,
#   'dam_built_year': nan,
#   'dam_removed_year': 2015.0,
#   'dam_height_ft': 38.6,
#   'dam_name': 'Morrow Lake Dam',
#   'stream_name': 'Flint Run',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ef088>},
#  {'_id': 'OH-065',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-065',
#   'latitude': 39.542304,
#   'longitude': -84.363254,
#   'dam_built_year': 1840.0,
#   'dam_removed_year': 1993.0,
#   'dam_height_ft': 10.0,
#   'dam_name': 'Middletown Hydraulic Dam',
#   'stream_name': 'Great Miami River',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ef188>},
#  {'_id': 'OH-066',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-066',
#   'latitude': 41.240612299999995,
#   'longitude': -80.8648078,
#   'dam_built_year': nan,
#   'dam_removed_year': 2005.0,
#   'dam_height_ft': 4.0,
#   'dam_name': 'Lovers Lane Dam',
#   'stream_name': 'Mahoning River',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ef288>},
#  {'_id': 'OH-067',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-067',
#   'latitude': 41.2389474,
#   'longitude': -80.8819869,
#   'dam_built_year': nan,
#   'dam_removed_year': 2005.0,
#   'dam_height_ft': 4.0,
#   'dam_name': 'North River Road Dam',
#   'stream_name': 'Mahoning River',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ef388>},
#  {'_id': 'OH-069',
#   'dam_source': 'Dam Removal Science',
#   'ar_id': 'OH-069',
#   'latitude': 40.135,
#   'longitude': -84.42166,
#   'dam_built_year': 1963.0,
#   'dam_removed_year': 2017.0,
#   'dam_height_ft': 14.5,
#   'dam_name': 'Bradford Sewage Lagoon I',
#   'stream_name': 'Offstream - near Ballinger Run',
#   'dam_alt_name': [],
#   'stream_alt_name': [],
#   'from_ar': [],
#   'in_drd': 1,
#   'geometry': <shapely.geometry.point.Point at 0x18bf77ef488>},
#  ...]

# %% [markdown]
# TESTS to CONSIDER

# %%
#tests if duplicates are occuring in dam_science_df, this might occur if incorrect columns are selected
def test_dup_dams(dam_science_df):
    '''
    Description
    -----------
    Test if duplicates are occuring in dam_science_df.
    This might occur if incorrect columns are selected in get_science_subset function
    
    Output
    -----------
    True: Duplicates exist, issue needs to be resolved
    False: No Duplicates, this test passes
    '''
    to_list = dam_science_df['DamAccessionNumber'].to_list()
    if len(to_list)==(len(list(set(to_list)))):
        return False
    else:
        return True
    
test_dup_dams(dam_science_df)
# Out:
# False

# %%
#tests if ar_ids are list in science that are no longer in ar
ar_in_science = dam_science_df['AR_ID'].dropna().to_list()
ar_ids = american_rivers_df['AR_ID'].to_list()
[i for i in ar_in_science if i not in ar_ids]
# Out:
# ['OR-027']

# %%
# tests if science dam without AR_ID is near an AR dam

# %%
# show dam removal science records that are getting extra data from american rivers (have missing data)
selection = [i for i in drip_dams if i['dam_source'] == 'Dam Removal Science' and len(i['from_ar'])>0]

df = pd.DataFrame(selection)
df.to_csv('dams_missing_info.csv', sep=',', index=False)
